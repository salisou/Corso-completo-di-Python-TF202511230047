# %% [markdown]
# # Caioooo Developers 😅

# %%
print('Ciaoooooooooooooooooooooooo LuuuuuuuuuuuuuuuuuuuuuuuCiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa')
# Out:
# Ciaoooooooooooooooooooooooo LuuuuuuuuuuuuuuuuuuuuuuuCiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
